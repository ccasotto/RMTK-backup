# %% [markdown]
# # Loss Modelling

# %% [markdown]
# This script processes event loss tables and calculates varies metrics such as loss exceedance curves, average annual losses, and losses for a number of return periods. It can also extract seismic events for specific levels of losses.
# <br />
# <br />
# It is necessary to include all of the event loss table outputs and associated stochastic event sets in the same folder (event_loss_table_folder).

# %%
from loss_modelling import lossModelling

event_loss_table_folder = 'ELT_Lisbon'
save_elt_csv = False
save_ses_csv = False
total_cost = 1.5416E+11
return_periods = [50,100,500]

lossModelling(event_loss_table_folder,save_ses_csv,save_elt_csv,total_cost,return_periods)
# Out:
# Maximum loss:
# 42294437540.0
# Average annual loss:
# 71651814.2046
# Average annual loss ratio (%):
# 0.0464788623538
# Loss for a return period of 50 years.
# 548463879.319
# Loss for a return period of 100 years.
# 1386506757.5
# Loss for a return period of 500 years.
# 6012852181.8

# %%
from loss_modelling import selectRuptures 
return_periods = [50,100,2450]
rups_for_return_period = 4
selectRuptures(event_loss_table_folder,return_periods,rups_for_return_period)
# Out:
# Ruptures causing losses for a return period of 50 years
#
# trt=03|ses=0001|src=0-1106|rup=025-01
# Mag: 6.45 Lon:-10.17 Lat:35.91 Depth:10.00
# trt=10|ses=0001|src=5-132|rup=001-01
# Mag: 4.05 Lon:-9.02 Lat:38.72 Depth:5.00
# trt=05|ses=0001|src=0-310|rup=027-01
# Mag: 6.65 Lon:-11.44 Lat:36.76 Depth:10.00
# trt=10|ses=0001|src=4-396|rup=004-01
# Mag: 4.35 Lon:-9.40 Lat:38.93 Depth:5.00
# Ruptures causing losses for a return period of 100 years
#
# trt=17|ses=0001|src=1-124|rup=027-01
# Mag: 6.65 Lon:-8.20 Lat:36.93 Depth:10.00
# trt=10|ses=0001|src=5-34|rup=017-01
# Mag: 5.65 Lon:-8.72 Lat:39.21 Depth:5.00
# trt=14|ses=0001|src=5-85|rup=011-01
# Mag: 5.05 Lon:-8.90 Lat:38.94 Depth:5.00
# trt=02|ses=0001|src=4-513|rup=015-01
# Mag: 5.45 Lon:-8.89 Lat:39.12 Depth:5.00
# Ruptures causing losses for a return period of 2450 years
#
# trt=12|ses=0001|src=4-642|rup=017-01
# Mag: 5.65 Lon:-9.12 Lat:38.81 Depth:5.00
# trt=08|ses=0001|src=6-65|rup=031-01
# Mag: 7.05 Lon:-8.63 Lat:38.74 Depth:5.00
# trt=16|ses=0001|src=5-103|rup=025-01
# Mag: 6.45 Lon:-8.96 Lat:38.85 Depth:5.00
# trt=10|ses=0001|src=6-65|rup=027-01
# Mag: 6.65 Lon:-8.62 Lat:38.74 Depth:5.00
