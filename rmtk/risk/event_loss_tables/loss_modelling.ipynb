# %% [markdown]
# # Loss Modelling

# %% [markdown]
# This script processes event loss tables and calculates varies metric such as loss exceedance curves, average annual losses, and loss for a number of return periods. It can also extract seismic events for specific levels of losses.

# %%
from loss_modelling import lossModelling

event_loss_table_folder = 'ELT_Lisbon'
save_elt_csv = False
save_ses_csv = False
total_cost = 1.5416E+11
return_periods = [100, 475, 950, 2750]

lossModelling(event_loss_table_folder,save_ses_csv,save_elt_csv,total_cost,return_periods)
# Out:
# Maximum loss:
# 42294437540.0
# Average annual loss:
# 71651814.2046
# Loss for a return period of 100 years.
# 1386506757.5
# Loss for a return period of 475 years.
# 5614491910.7
# Loss for a return period of 950 years.
# 11026718862.9
# Loss for a return period of 2750 years.
# 27234199336.8

# %%
from loss_modelling import selectRuptures 
return_periods = [100, 475, 2750]
rups_for_return_period = 5
selectRuptures(event_loss_table_folder,return_periods,rups_for_return_period)
# Out:
# Ruptures causing losses for a return period of 100 years
#
# trt=17|ses=0001|src=1-124|rup=027-01
# Mag: 6.65 Lon:-8.20 Lat:36.93 Depth:10.00
# trt=10|ses=0001|src=5-34|rup=017-01
# Mag: 5.65 Lon:-8.72 Lat:39.21 Depth:5.00
# trt=14|ses=0001|src=5-85|rup=011-01
# Mag: 5.05 Lon:-8.90 Lat:38.94 Depth:5.00
# trt=02|ses=0001|src=4-513|rup=015-01
# Mag: 5.45 Lon:-8.89 Lat:39.12 Depth:5.00
# trt=16|ses=0001|src=5-99|rup=006-01
# Mag: 4.55 Lon:-9.19 Lat:38.85 Depth:5.00
# Ruptures causing losses for a return period of 475 years
#
# trt=12|ses=0001|src=4-854|rup=023-01
# Mag: 6.25 Lon:-9.18 Lat:38.27 Depth:5.00
# trt=18|ses=0001|src=4-716|rup=012-01
# Mag: 5.15 Lon:-9.24 Lat:38.63 Depth:5.00
# trt=08|ses=0001|src=5-106|rup=018-01
# Mag: 5.75 Lon:-8.79 Lat:38.85 Depth:5.00
# trt=18|ses=0001|src=4-681|rup=011-01
# Mag: 5.05 Lon:-9.06 Lat:38.72 Depth:5.00
# trt=08|ses=0001|src=6-42|rup=029-01
# Mag: 6.85 Lon:-8.16 Lat:38.88 Depth:5.00
# Ruptures causing losses for a return period of 2750 years
# ...
