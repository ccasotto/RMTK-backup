# %% [markdown]
# # Loss Modelling

# %% [markdown]
# This script processes event loss tables and calculates varies metrics such as loss exceedance curves, average annual losses, and losses for a number of return periods. It can also extract seismic events for specific levels of losses.
# <br />
# <br />
# It is necessary to include all of the event loss table outputs and associated stochastic event sets in the same folder (event_loss_table_folder).

# %%
from loss_modelling import lossModelling

event_loss_table_folder = 'Nepal'
save_elt_csv = False
save_ses_csv = False
total_cost = 1.5416E+11
return_periods = [50,100,500]

lossModelling(event_loss_table_folder,save_ses_csv,save_elt_csv,total_cost,return_periods)
# Out:
# Maximum loss:
# 3101296642.7
# Average annual loss:
# 355737105.997
# Average annual loss ratio (%):
# 0.230758371819
# Loss for a return period of 50 years.
# 1391082654.37
# Loss for a return period of 100 years.
# 1835030715.37
# Return period of 500 years is above the time length of the stochastic event set.

# %%
from loss_modelling import selectRuptures 
return_periods = [50,100,500]
rups_for_return_period = 4
selectRuptures(event_loss_table_folder,return_periods,rups_for_return_period)
# Out:
# Return period of 500 years is above the time length of the stochastic event set.
# Ruptures causing losses for a return period of 50 years
#
# smlt=00|ses=0008|src=230-281|rup=003-01
# Mag: 6.25 Lon:86.86 Lat:26.81 Depth:15.00
# smlt=00|ses=0005|src=232-104|rup=004-01
# Mag: 6.75 Lon:84.48 Lat:28.32 Depth:15.00
# smlt=00|ses=0005|src=230-121|rup=002-01
# Mag: 5.75 Lon:85.35 Lat:27.26 Depth:15.00
# smlt=00|ses=0005|src=229-53|rup=004-01
# Mag: 6.75 Lon:85.77 Lat:28.04 Depth:15.00
# Ruptures causing losses for a return period of 100 years
#
# smlt=00|ses=0003|src=230-193|rup=004-01
# Mag: 6.75 Lon:86.56 Lat:27.08 Depth:15.00
# smlt=00|ses=0008|src=231-225|rup=005-01
# Mag: 7.25 Lon:83.78 Lat:27.50 Depth:15.00
# smlt=00|ses=0008|src=230-20|rup=002-01
# Mag: 5.75 Lon:85.36 Lat:27.71 Depth:15.00
# smlt=00|ses=0006|src=230-18|rup=002-01
# Mag: 5.75 Lon:85.15 Lat:27.71 Depth:15.00
